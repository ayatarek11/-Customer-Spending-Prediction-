# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df=pd.read_csv(r"C:\Users\Lenovo\Downloads\archive (3)\Ecommerce Customers")

# %%
print(df)
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
df.shape
# Out:
# (500, 8)

# %%
df.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
df.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
# time on website vs yearly amount spent
sns.jointplot(x='Time on Website', y='Yearly Amount Spent', data=df, alpha=0.4)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Calculate the percentage of null values
null_percentage = df.isnull().sum() / len(df) * 100
print(null_percentage)
# Out:
# Email                   0.0
# Address                 0.0
# Avatar                  0.0
# Avg. Session Length     0.0
# Time on App             0.0
# Time on Website         0.0
# Length of Membership    0.0
# Yearly Amount Spent     0.0
# dtype: float64

# %%
sns.pairplot(df, 
             kind='scatter', 
             plot_kws={'alpha':0.4}, 
             diag_kws={'alpha':0.55, 'bins':40})
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df['Time on App'].quantile(0.25)
Q3 = df['Time on App'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
outliers = df[(df['Time on App'] < lower_bound) | (df['Time on App'] > upper_bound)]

print(f"Outliers in 'Time on App':\n{outliers}")
# Out:
# Outliers in 'Time on App':
#                                 Email  \
# 65                     kyang@diaz.org
# 309                  dblair@gmail.com
# 362                   cruiz@yahoo.com
# 442  martinkristi@sanchez-coleman.com
#
#                                                Address           Avatar  \
# 65    223 Love Trail Suite 831\nPort Jeffrey, IN 46849        OliveDrab
# 309     190 Kelley Burg\nWest Juliaport, IA 35826-8163  MediumSlateBlue
# 362  497 Julian Brook Suite 872\nHillberg, FM 87927...      LightSalmon
# 442                   PSC 1893, Box 7023\nAPO AA 73445             Lime
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 65             34.374258    15.126994        37.157624              5.377594
# 309            34.102279     8.508152        35.462400              1.838211
# 362            33.981006     9.316289        36.914952              2.868428
# ...

# %%
# Plot a box plot for 'Time on App'
sns.boxplot(x=df['Time on App'])
plt.title('Box Plot of Time on App')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Apply Label Encoding for each of the columns
df['Email_encoded'] = label_encoder.fit_transform(df['Email'])
df['Address_encoded'] = label_encoder.fit_transform(df['Address'])
df['Avatar_encoded'] = label_encoder.fit_transform(df['Avatar'])

# Show the encoded columns
print(df[['Email', 'Email_encoded', 'Address', 'Address_encoded', 'Avatar', 'Avatar_encoded']].head())
# Out:
#                            Email  Email_encoded  \
# 0      mstephenson@fernandez.com            342
# 1              hduke@hotmail.com            190
# 2               pallen@yahoo.com            355
# 3        riverarebecca@gmail.com            391
# 4  mstephens@davidson-herman.com            341
#
#                                              Address  Address_encoded  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605              381
# 1     4547 Archer Common\nDiazchester, CA 06566-8576              226
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...              123
# 3   1414 David Throughway\nPort Jason, OH 22070-1220               62
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...               60
#
#              Avatar  Avatar_encoded
# 0            Violet             132
# 1         DarkGreen              25
# 2            Bisque               6
# 3       SaddleBrown             114
# 4  MediumAquaMarine              80

# %%
df['App_to_Web_Ratio'] = df['Time on App'] / df['Time on Website']

# %%
df.info
# Out:
# <bound method DataFrame.info of                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ...

# %%
print(df['App_to_Web_Ratio'])
# Out:
# 0      0.319767
# 1      0.298089
# 2      0.305311
# 3      0.373558
# 4      0.340872
#          ...
# 495    0.372513
# 496    0.314484
# 497    0.299991
# 498    0.336357
# 499    0.347175
# Name: App_to_Web_Ratio, Length: 500, dtype: float64

# %%
sns.scatterplot(x='Length of Membership', y='Yearly Amount Spent', data=df)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.boxplot(x=df['Avatar'], y=df['Yearly Amount Spent'])
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
correlation = df['Time on App'].corr(df['Time on Website'])
print("Correlation between Time on App and Time on Website:", correlation)
# Out:
# Correlation between Time on App and Time on Website: 0.08238827319098196

# %%
correlation = df['Length of Membership'].corr(df['Yearly Amount Spent'])
print("Correlation between Length of Membership and Yearly Amount Spent:", correlation)
# Out:
# Correlation between Length of Membership and Yearly Amount Spent: 0.809083568247581

# %%
df.info
# Out:
# <bound method DataFrame.info of                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ...

# %%
# Show the encoded columns
print(df[['Email', 'Email_encoded', 'Address', 'Address_encoded', 'Avatar', 'Avatar_encoded']].head())
# Out:
#                            Email  Email_encoded  \
# 0      mstephenson@fernandez.com            342
# 1              hduke@hotmail.com            190
# 2               pallen@yahoo.com            355
# 3        riverarebecca@gmail.com            391
# 4  mstephens@davidson-herman.com            341
#
#                                              Address  Address_encoded  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605              381
# 1     4547 Archer Common\nDiazchester, CA 06566-8576              226
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...              123
# 3   1414 David Throughway\nPort Jason, OH 22070-1220               62
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...               60
#
#              Avatar  Avatar_encoded
# 0            Violet             132
# 1         DarkGreen              25
# 2            Bisque               6
# 3       SaddleBrown             114
# 4  MediumAquaMarine              80

# %%
# Boxplot for 'Email_encoded' and 'Yearly Amount Spent'
sns.boxplot(x='Email_encoded', y='Yearly Amount Spent', data=df)
plt.title('Boxplot of Email_encoded vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Boxplot for 'Address_encoded' and 'Yearly Amount Spent'
sns.boxplot(x='Address_encoded', y='Yearly Amount Spent', data=df)
plt.title('Boxplot of Address_encoded vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Boxplot for 'Avatar_encoded' and 'Yearly Amount Spent'
sns.boxplot(x='Avatar_encoded', y='Yearly Amount Spent', data=df)
plt.title('Boxplot of Avatar_encoded vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Calculate the correlation matrix including encoded columns
correlation_matrix = df[['Email_encoded', 'Address_encoded', 'Avatar_encoded', 
                         'Time on App', 'Yearly Amount Spent', 'Length of Membership']].corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap including Encoded Columns')
plt.show()

# %%
# Scatterplot for 'Email_encoded' vs 'Yearly Amount Spent'
sns.scatterplot(x='Email_encoded', y='Yearly Amount Spent', data=df)
plt.title('Scatterplot of Email_encoded vs Yearly Amount Spent')
plt.show()

# Scatterplot for 'Address_encoded' vs 'Yearly Amount Spent'
sns.scatterplot(x='Address_encoded', y='Yearly Amount Spent', data=df)
plt.title('Scatterplot of Address_encoded vs Yearly Amount Spent')
plt.show()

# Scatterplot for 'Avatar_encoded' vs 'Yearly Amount Spent'
sns.scatterplot(x='Avatar_encoded', y='Yearly Amount Spent', data=df)
plt.title('Scatterplot of Avatar_encoded vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Violin plot بين "Length of Membership" و "Yearly Amount Spent"
sns.violinplot(x='Length of Membership', y='Yearly Amount Spent', data=df)
plt.title('Violin Plot: Length of Membership vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x='Time on Website', y='Yearly Amount Spent', data=df)
plt.title('Scatter Plot: Time on Website vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.scatterplot(x='Length of Membership', y='Yearly Amount Spent', data=df)
plt.title('Scatter Plot: Length of Membership vs Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(x='Email_encoded', y='Yearly Amount Spent', data=df)
plt.title('Bar Plot: Email_encoded vs Yearly Amount Spent')
plt.xlabel('Encoded Email')
plt.ylabel('Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(x='Time on App', y='Yearly Amount Spent', data=df)
plt.title('Bar Plot: Time on App vs Yearly Amount Spent')
plt.xlabel('Time on App')
plt.ylabel('Yearly Amount Spent')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
sns.barplot(x='Time on App', y='Length of Membership', data=df)
plt.title('Bar Plot: Time on App vs Length of Membership')
plt.xlabel('Time on App')
plt.ylabel('Length of Membership')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
from sklearn.model_selection import train_test_split

X = df.drop('Yearly Amount Spent', axis=1)  
y = df['Yearly Amount Spent']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Training data (X_train):", X_train.shape)
print("Testing data (X_test):", X_test.shape)
print("Training target (y_train):", y_train.shape)
print("Testing target (y_test):", y_test.shape)
# Out:
# Training data (X_train): (350, 11)
# Testing data (X_test): (150, 11)
# Training target (y_train): (350,)
# Testing target (y_test): (150,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Initialize models
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "Support Vector Regressor": SVR()
}

# %%
# Step 1: Label Encoding for categorical columns (Email, Address, Avatar)
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
label_encoder = LabelEncoder()

# Apply Label Encoding for the categorical columns
df['Email_encoded'] = label_encoder.fit_transform(df['Email'])
df['Address_encoded'] = label_encoder.fit_transform(df['Address'])
df['Avatar_encoded'] = label_encoder.fit_transform(df['Avatar'])

# Step 2: Separate the features (X) and target (y)
X = df[['Email_encoded', 'Address_encoded', 'Avatar_encoded', 'Time on App', 'Time on Website', 'Length of Membership']]
y = df['Yearly Amount Spent']

# Step 3: Train-Test Split (70% Train, 30% Test)
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 4: Define a function to evaluate the models
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)  # Train the model
    y_pred = model.predict(X_test)  # Make predictions
    
    # Calculate evaluation metrics
    mae = mean_absolute_error(y_test, y_pred)  # MAE
    mse = mean_squared_error(y_test, y_pred)  # MSE
    rmse = np.sqrt(mse)  # RMSE
    r2 = r2_score(y_test, y_pred)  # R2
    
    return mae, mse, rmse, r2

# Step 5: Initialize and Train Multiple Models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Define models to evaluate
models = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor()
}

# Store the results
results = {}

# Train each model and evaluate
for name, model in models.items():
    print(f"Training {name}...")
    mae, mse, rmse, r2 = evaluate_model(model, X_train, y_train, X_test, y_test)
    results[name] = {
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2
    }

# Print the results for each model
for name, result in results.items():
    print(f"\nResults for {name}:")
    print(f"MAE: {result['MAE']}")
    print(f"MSE: {result['MSE']}")
    print(f"RMSE: {result['RMSE']}")
    print(f"R2: {result['R2']}")
# Out:
# Training Linear Regression...
# Training Decision Tree...
# Training Random Forest...
#
# Results for Linear Regression:
# MAE: 22.410580648362945
# MSE: 749.7733763332863
# RMSE: 27.381989999510377
# R2: 0.8620144520949793
#
# Results for Decision Tree:
# MAE: 30.34533067545292
# MSE: 1548.5998195239617
# RMSE: 39.35225304253826
# R2: 0.7150013573066059
#
# Results for Random Forest:
# MAE: 23.502764917263484
# MSE: 868.1037773867744
# RMSE: 29.463600889687164
# R2: 0.8402373581909028

# %%
# Compare models based on the evaluation metrics
for name, result in results.items():
    print(f"\nResults for {name}:")
    print(f"MAE: {result['MAE']}")
    print(f"MSE: {result['MSE']}")
    print(f"RMSE: {result['RMSE']}")
    print(f"R2: {result['R2']}")
# Out:
# Results for Linear Regression:
# MAE: 22.410580648362945
# MSE: 749.7733763332863
# RMSE: 27.381989999510377
# R2: 0.8620144520949793
#
# Results for Decision Tree:
# MAE: 30.34533067545292
# MSE: 1548.5998195239617
# RMSE: 39.35225304253826
# R2: 0.7150013573066059
#
# Results for Random Forest:
# MAE: 23.502764917263484
# MSE: 868.1037773867744
# RMSE: 29.463600889687164
# R2: 0.8402373581909028
